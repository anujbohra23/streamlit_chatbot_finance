# %%
import os
import streamlit as st
import pickle
import time
import langchain
from langchain import OpenAI
from langchain.chains import RetrievalQAWithSourcesChain
from langchain.chains.qa_with_sources.loading import load_qa_with_sources_chain
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import UnstructuredURLLoader
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS

# %%
# !pip install openai

# %%
#load openAI api key
os.environ['OPENAI_API_KEY'] = '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'

# %%
# Initialise LLM with required params
llm = OpenAI(temperature=0.9, max_tokens=500)
# Out:
# C:\Users\Anuj Bohra\anaconda3\envs\lllmspace\Lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.llms.openai.OpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAI`.
#   warn_deprecated(

# %% [markdown]
# ### (1) Load data

# %%
# !pip install unstructured libmagic python-magic python-magic-bin
# Out:
# Requirement already satisfied: unstructured in c:\users\anuj bohra\anaconda3\envs\lllmspace\lib\site-packages (0.12.4)
# Requirement already satisfied: libmagic in c:\users\anuj bohra\anaconda3\envs\lllmspace\lib\site-packages (1.0)
# Requirement already satisfied: python-magic in c:\users\anuj bohra\anaconda3\envs\lllmspace\lib\site-packages (0.4.27)
# Requirement already satisfied: python-magic-bin in c:\users\anuj bohra\anaconda3\envs\lllmspace\lib\site-packages (0.4.14)
# Requirement already satisfied: chardet in c:\users\anuj bohra\appdata\roaming\python\python311\site-packages (from unstructured) (5.2.0)
# Requirement already satisfied: filetype in c:\users\anuj bohra\anaconda3\envs\lllmspace\lib\site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: lxml in c:\users\anuj bohra\appdata\roaming\python\python311\site-packages (from unstructured) (4.9.3)
# Requirement already satisfied: nltk in c:\users\anuj bohra\appdata\roaming\python\python311\site-packages (from unstructured) (3.8.1)
# Requirement already satisfied: tabulate in c:\users\anuj bohra\appdata\roaming\python\python311\site-packages (from unstructured) (0.9.0)
# Requirement already satisfied: requests in c:\users\anuj bohra\appdata\roaming\python\python311\site-packages (from unstructured) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\anuj bohra\appdata\roaming\python\python311\site-packages (from unstructured) (4.12.2)
# Requirement already satisfied: emoji in c:\users\anuj bohra\anaconda3\envs\lllmspace\lib\site-packages (from unstructured) (2.10.1)
# Requirement already satisfied: dataclasses-json in c:\users\anuj bohra\anaconda3\envs\lllmspace\lib\site-packages (from unstructured) (0.6.4)
# Requirement already satisfied: python-iso639 in c:\users\anuj bohra\anaconda3\envs\lllmspace\lib\site-packages (from unstructured) (2024.2.7)
# Requirement already satisfied: langdetect in c:\users\anuj bohra\anaconda3\envs\lllmspace\lib\site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: numpy in c:\users\anuj bohra\appdata\roaming\python\python311\site-packages (from unstructured) (1.24.3)
# Requirement already satisfied: rapidfuzz in c:\users\anuj bohra\appdata\roaming\python\python311\site-packages (from unstructured) (3.6.0)
# Requirement already satisfied: backoff in c:\users\anuj bohra\anaconda3\envs\lllmspace\lib\site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: typing-extensions in c:\users\anuj bohra\appdata\roaming\python\python311\site-packages (from unstructured) (4.8.0)
# Requirement already satisfied: unstructured-client>=0.15.1 in c:\users\anuj bohra\anaconda3\envs\lllmspace\lib\site-packages (from unstructured) (0.18.0)
# Requirement already satisfied: wrapt in c:\users\anuj bohra\appdata\roaming\python\python311\site-packages (from unstructured) (1.14.1)
# Requirement already satisfied: certifi>=2023.7.22 in c:\users\anuj bohra\appdata\roaming\python\python311\site-packages (from unstructured-client>=0.15.1->unstructured) (2023.7.22)
# Requirement already satisfied: charset-normalizer>=3.2.0 in c:\users\anuj bohra\appdata\roaming\python\python311\site-packages (from unstructured-client>=0.15.1->unstructured) (3.2.0)
# Requirement already satisfied: dataclasses-json-speakeasy>=0.5.11 in c:\users\anuj bohra\anaconda3\envs\lllmspace\lib\site-packages (from unstructured-client>=0.15.1->unstructured) (0.5.11)
# Requirement already satisfied: idna>=3.4 in c:\users\anuj bohra\appdata\roaming\python\python311\site-packages (from unstructured-client>=0.15.1->unstructured) (3.4)
# Requirement already satisfied: jsonpath-python>=1.0.6 in c:\users\anuj bohra\anaconda3\envs\lllmspace\lib\site-packages (from unstructured-client>=0.15.1->unstructured) (1.0.6)
# Requirement already satisfied: marshmallow>=3.19.0 in c:\users\anuj bohra\anaconda3\envs\lllmspace\lib\site-packages (from unstructured-client>=0.15.1->unstructured) (3.20.2)
# Requirement already satisfied: mypy-extensions>=1.0.0 in c:\users\anuj bohra\appdata\roaming\python\python311\site-packages (from unstructured-client>=0.15.1->unstructured) (1.0.0)
# Requirement already satisfied: packaging>=23.1 in c:\users\anuj bohra\anaconda3\envs\lllmspace\lib\site-packages (from unstructured-client>=0.15.1->unstructured) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\anuj bohra\appdata\roaming\python\python311\site-packages (from unstructured-client>=0.15.1->unstructured) (2.8.2)
# Requirement already satisfied: six>=1.16.0 in c:\users\anuj bohra\appdata\roaming\python\python311\site-packages (from unstructured-client>=0.15.1->unstructured) (1.16.0)
# Requirement already satisfied: typing-inspect>=0.9.0 in c:\users\anuj bohra\anaconda3\envs\lllmspace\lib\site-packages (from unstructured-client>=0.15.1->unstructured) (0.9.0)
# Requirement already satisfied: urllib3>=1.26.18 in c:\users\anuj bohra\anaconda3\envs\lllmspace\lib\site-packages (from unstructured-client>=0.15.1->unstructured) (2.1.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\anuj bohra\appdata\roaming\python\python311\site-packages (from beautifulsoup4->unstructured) (2.5)
# Requirement already satisfied: click in c:\users\anuj bohra\appdata\roaming\python\python311\site-packages (from nltk->unstructured) (8.1.3)
# Requirement already satisfied: joblib in c:\users\anuj bohra\appdata\roaming\python\python311\site-packages (from nltk->unstructured) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\anuj bohra\appdata\roaming\python\python311\site-packages (from nltk->unstructured) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\anuj bohra\appdata\roaming\python\python311\site-packages (from nltk->unstructured) (4.66.1)
# Requirement already satisfied: colorama in c:\users\anuj bohra\appdata\roaming\python\python311\site-packages (from click->nltk->unstructured) (0.4.6)

# %%
pip list
# Out:
# Package                      Version
# ---------------------------- -----------
# absl-py                      2.0.0
# aiohttp                      3.8.6
# aiosignal                    1.3.1
# altair                       5.0.1
# annotated-types              0.5.0
# anyio                        4.0.0
# argon2-cffi                  23.1.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.3.0
# asttokens                    2.2.1
# astunparse                   1.6.3
# async-lru                    2.0.4
# async-timeout                4.0.3
# attrs                        23.1.0
# Babel                        2.13.1
# backcall                     0.2.0
# backoff                      2.2.1
# beautifulsoup4               4.12.2
# black                        23.7.0
# bleach                       6.1.0
# blinker                      1.6.2
# blis                         0.7.11
# boto3                        1.28.73
# botocore                     1.31.73
# Bottleneck                   1.3.5
# Brotli                       1.1.0
# cachetools                   5.3.1
# catalogue                    2.0.10
# certifi                      2023.7.22
# cffi                         1.16.0
# chardet                      5.2.0
# charset-normalizer           3.2.0
# chart-studio                 1.1.0
# click                        8.1.3
# cloudpathlib                 0.15.1
# cmake                        3.27.0
# colorama                     0.4.6
# colorlover                   0.3.0
# comm                         0.1.4
# confection                   0.1.3
# contourpy                    1.0.7
# cryptography                 41.0.7
# cufflinks                    0.17.3
# cv                           1.0.0
# cycler                       0.11.0
# cymem                        2.0.8
# dataclasses-json             0.6.4
# dataclasses-json-speakeasy   0.5.11
# datasets                     2.14.6
# debugpy                      1.6.6
# decorator                    5.1.1
# defusedxml                   0.7.1
# dill                         0.3.7
# Distance                     0.1.3
# distro                       1.9.0
# dlib                         19.24.1
# docx2txt                     0.8
# emoji                        2.10.1
# en-core-web-sm               3.7.1
# ensure                       1.0.2
# entrypoints                  0.4
# et-xmlfile                   1.1.0
# exceptiongroup               1.2.0
# executing                    1.2.0
# face-recognition             1.3.0
# face-recognition-models      0.3.0
# faiss-cpu                    1.7.4
# Faker                        22.4.0
# fastapi                      0.78.0
# fastjsonschema               2.18.1
# favicon                      0.7.0
# filelock                     3.12.4
# filetype                     1.2.0
# Flask                        2.3.2
# Flask-Cors                   4.0.0
# Flask-SQLAlchemy             3.1.1
# flatbuffers                  23.5.26
# fonttools                    4.39.3
# fqdn                         1.5.1
# frozenlist                   1.4.0
# fsspec                       2023.9.2
# fuzzywuzzy                   0.18.0
# gast                         0.4.0
# gitdb                        4.0.11
# GitPython                    3.1.40
# google-auth                  2.23.0
# google-auth-oauthlib         1.0.0
# google-pasta                 0.2.0
# greenlet                     2.0.2
# grpcio                       1.58.0
# gunicorn                     21.2.0
# h11                          0.14.0
# h5py                         3.9.0
# htbuilder                    0.6.2
# httpcore                     1.0.2
# httpx                        0.26.0
# huggingface-hub              0.16.4
# idna                         3.4
# importlib-metadata           6.11.0
# inflate64                    0.3.1
# iniconfig                    2.0.0
# ipykernel                    6.21.2
# ipython                      8.11.0
# ipython-genutils             0.2.0
# ipywidgets                   8.1.0
# isoduration                  20.11.0
# itsdangerous                 2.1.2
# jedi                         0.18.2
# Jinja2                       3.1.2
# jmespath                     1.0.1
# joblib                       1.3.2
# json5                        0.9.14
# jsonpatch                    1.33
# jsonpath-python              1.0.6
# jsonpointer                  2.4
# jsonschema                   4.19.1
# jsonschema-specifications    2023.7.1
# jupyter_client               8.0.3
# jupyter_core                 5.2.0
# jupyter-events               0.8.0
# jupyter-lsp                  2.2.0
# jupyter_server               2.9.1
# jupyter_server_terminals     0.4.4
# jupyterlab                   4.0.7
# jupyterlab-pygments          0.2.2
# jupyterlab_server            2.25.0
# jupyterlab-widgets           3.0.8
# keras                        2.15.0
# kiwisolver                   1.4.4
# langchain                    0.1.6
# langchain-community          0.0.19
# langchain-core               0.1.22
# langcodes                    3.3.0
# langdetect                   1.0.9
# langsmith                    0.0.90
# Levenshtein                  0.23.0
# libclang                     16.0.6
# libmagic                     1.0
# lxml                         4.9.3
# Markdown                     3.5.2
# markdown-it-py               3.0.0
# markdownlit                  0.0.7
# MarkupSafe                   2.1.2
# marshmallow                  3.20.2
# matplotlib                   3.7.1
# matplotlib-inline            0.1.6
# mdurl                        0.1.2
# mistune                      3.0.2
# mkl-fft                      1.3.8
# mkl-random                   1.2.4
# mkl-service                  2.4.0
# ml-dtypes                    0.2.0
# mlxtend                      0.23.1
# more-itertools               10.2.0
# mpmath                       1.3.0
# multidict                    6.0.4
# multiprocess                 0.70.15
# multivolumefile              0.2.3
# murmurhash                   1.0.10
# mypy-boto3-s3                1.28.55
# mypy-extensions              1.0.0
# mysql-connector-python       8.3.0
# nbclient                     0.8.0
# nbconvert                    7.9.2
# nbformat                     5.9.2
# nest-asyncio                 1.5.6
# networkx                     3.1
# nltk                         3.8.1
# notebook                     7.0.6
# notebook_shim                0.2.3
# numerize                     0.12
# numexpr                      2.8.7
# numpy                        1.24.3
# oauthlib                     3.2.2
# openai                       1.12.0
# opencv-python                4.8.0.74
# openpyxl                     3.1.2
# opt-einsum                   3.3.0
# overrides                    7.4.0
# packaging                    23.2
# pafy                         0.5.5
# pandas                       2.0.1
# pandocfilters                1.5.0
# parso                        0.8.3
# pathspec                     0.11.2
# pathy                        0.10.2
# pdfminer.six                 20231228
# pdfminer3                    2018.12.3.0
# pickleshare                  0.7.5
# Pillow                       9.5.0
# pip                          23.3.1
# platformdirs                 3.1.0
# plotly                       5.16.1
# pluggy                       1.4.0
# portalocker                  2.8.2
# preshed                      3.0.9
# prometheus-client            0.17.1
# prompt-toolkit               3.0.38
# protobuf                     3.20.3
# psutil                       5.9.4
# pure-eval                    0.2.2
# py7zr                        0.20.6
# pyarrow                      13.0.0
# pyasn1                       0.5.0
# pyasn1-modules               0.3.0
# pybcj                        1.0.1
# pycparser                    2.21
# pycryptodome                 3.19.1
# pycryptodomex                3.19.0
# pydantic                     1.10.13
# pydantic_core                2.10.1
# pydeck                       0.8.1b0
# Pygments                     2.14.0
# pymdown-extensions           10.7
# PyMySQL                      1.1.0
# pyparsing                    3.0.9
# pyppmd                       1.0.0
# pyresparser                  1.0.6
# pyrsistent                   0.20.0
# pytest                       8.0.0
# pytest-subtests              0.11.0
# python-box                   6.0.2
# python-dateutil              2.8.2
# python-iso639                2024.2.7
# python-json-logger           2.0.7
# python-Levenshtein           0.23.0
# python-magic                 0.4.27
# python-magic-bin             0.4.14
# pytz                         2023.3
# pywin32                      305
# pywinpty                     2.0.12
# PyYAML                       6.0.1
# pyzmq                        25.0.0
# pyzstd                       0.15.9
# rapidfuzz                    3.6.0
# referencing                  0.30.2
# regex                        2023.10.3
# requests                     2.31.0
# requests-oauthlib            1.3.1
# retrying                     1.3.4
# rfc3339-validator            0.1.4
# rfc3986-validator            0.1.1
# rich                         13.7.0
# rouge-score                  0.1.2
# rpds-py                      0.10.3
# rsa                          4.9
# s3transfer                   0.7.0
# sacrebleu                    2.3.1
# safetensors                  0.3.3
# scikit-learn                 1.3.2
# scipy                        1.11.3
# seaborn                      0.12.2
# Send2Trash                   1.8.2
# sentence-transformers        2.3.1
# sentencepiece                0.1.99
# setuptools                   68.2.2
# six                          1.16.0
# smart-open                   6.4.0
# smmap                        5.0.1
# sniffio                      1.3.0
# sortedcontainers             2.4.0
# soupsieve                    2.5
# spacy                        3.7.2
# spacy-legacy                 3.0.12
# spacy-loggers                1.0.5
# SQLAlchemy                   2.0.21
# srsly                        2.4.8
# st-annotated-text            4.0.1
# stack-data                   0.6.2
# starlette                    0.19.1
# streamlit                    1.30.0
# streamlit-camera-input-live  0.2.0
# streamlit-card               1.0.0
# streamlit-embedcode          0.1.2
# streamlit-extras             0.3.6
# streamlit-faker              0.0.3
# streamlit-image-coordinates  0.1.6
# streamlit-keyup              0.2.2
# streamlit-option-menu        0.3.12
# streamlit-tags               1.2.8
# streamlit-toggle-switch      1.0.2
# streamlit-vertical-slider    2.5.5
# sympy                        1.12
# tabulate                     0.9.0
# tenacity                     8.2.3
# tensorboard                  2.15.1
# tensorboard-data-server      0.7.1
# tensorflow                   2.15.0
# tensorflow-estimator         2.15.0
# tensorflow-intel             2.15.0
# tensorflow-io-gcs-filesystem 0.31.0
# termcolor                    2.3.0
# terminado                    0.17.1
# texttable                    1.7.0
# thinc                        8.2.1
# threadpoolctl                3.2.0
# tinycss2                     1.2.1
# tokenizers                   0.14.0
# toml                         0.10.2
# tomli                        2.0.1
# toolz                        0.12.0
# torch                        2.0.1
# torchvision                  0.15.2
# tornado                      6.2
# tqdm                         4.66.1
# traitlets                    5.9.0
# transformers                 4.34.0
# typer                        0.7.0
# types-python-dateutil        2.8.19.14
# typing_extensions            4.8.0
# typing-inspect               0.9.0
# tzdata                       2023.3
# tzlocal                      5.2
# unstructured                 0.12.4
# unstructured-client          0.18.0
# uri-template                 1.3.0
# urllib3                      2.1.0
# uvicorn                      0.18.3
# validators                   0.22.0
# wasabi                       1.1.2
# watchdog                     3.0.0
# wcwidth                      0.2.6
# weasel                       0.3.1
# webcolors                    1.13
# webencodings                 0.5.1
# websocket-client             1.6.4
# Werkzeug                     2.3.3
# wheel                        0.41.2
# widgetsnbextension           4.0.8
# wordcloud                    1.9.2
# wrapt                        1.14.1
# xgboost                      2.0.0
# xxhash                       3.4.1
# yarl                         1.9.2
# youtube-dl                   2021.12.17
# zipp                         3.17.0
# Note: you may need to restart the kernel to use updated packages.

# %%
loaders = UnstructuredURLLoader(urls=[
    "https://www.moneycontrol.com/news/business/markets/wall-street-rises-as-tesla-soars-on-ai-optimism-11351111.html",
    "https://www.moneycontrol.com/news/business/tata-motors-launches-punch-icng-price-starts-at-rs-7-1-lakh-11098751.html"
])
data = loaders.load() 
len(data)

# %%
data

# %% [markdown]
# ### (2) Split data to create chunks

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)

# As data is of type documents we can directly use split_documents over split_text in order to get the chunks.
docs = text_splitter.split_documents(data)

# %%
len(docs)

# %%
docs[0]

# %% [markdown]
# ### (3) Create embeddings for these chunks and save them to FAISS index

# %%
# Create the embeddings of the chunks using openAIEmbeddings
embeddings = OpenAIEmbeddings()

# Pass the documents and embeddings inorder to create FAISS vector index
vectorindex_openai = FAISS.from_documents(docs, embeddings)

# %%
# Storing vector index create in local
file_path="vector_index.pkl"
with open(file_path, "wb") as f:
    pickle.dump(vectorindex_openai, f)

# %%
if os.path.exists(file_path):
    with open(file_path, "rb") as f:
        vectorIndex = pickle.load(f)

# %% [markdown]
# ### (4) Retrieve similar embeddings for a given question and call LLM to retrieve final answer

# %%
chain = RetrievalQAWithSourcesChain.from_llm(llm=llm, retriever=vectorIndex.as_retriever())
chain

# %%
query = "what is the price of Tiago iCNG?"
# query = "what are the main features of punch iCNG?"

langchain.debug=True

chain({"question": query}, return_only_outputs=True)
